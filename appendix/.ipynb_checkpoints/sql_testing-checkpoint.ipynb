# %%
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import types
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
from sqlalchemy import inspect
from sqlalchemy.sql import text
import pandas as pd

# %%
# Establish connection to SQL
engine = create_engine("mysql://root:password@localhost/weather_data")

# %%
dtype={ 
    'city':  sqlalchemy.types.VARCHAR(length=255),
    'type': sqlalchemy.types.VARCHAR(length=255),
    'county': sqlalchemy.types.VARCHAR(length=255),
    'state': sqlalchemy.types.VARCHAR(length=255),
    'lat': sqlalchemy.types.Float(precision=8, asdecimal=True),
    'lng': sqlalchemy.types.Float(precision=8, asdecimal=True),
    'uv_index': sqlalchemy.types.Float(precision=2, asdecimal=True),
    'aqi': sqlalchemy.types.Float(precision=2, asdecimal=True),
    'category': sqlalchemy.types.VARCHAR(length=255),
    'dominant_pollutant': sqlalchemy.types.VARCHAR(length=255),
    'date': sqlalchemy.DateTime(),
    'temperature': sqlalchemy.types.Float(precision=2, asdecimal=True),
    'cloud': sqlalchemy.types.INTEGER(),
    'pressure': sqlalchemy.types.Float(precision=2, asdecimal=True),
    'wind_speed': sqlalchemy.types.Float(precision=2, asdecimal=True),
    'rain': sqlalchemy.types.Float(precision=2, asdecimal=True)
}

# %%
def format_date(df):
    df['date'] = pd.to_datetime(df['date'])
    return df

# %%
def push_to_sql(df,table_name):
    
    # Get dictionaries for each row
    data = df.to_dict(orient='index').values()
    
    columns = ','.join(df.columns)
    col_values = ','.join([f':{col}' for col in df.columns])

    with engine.connect() as con:

        test_statement=text(f"""
            INSERT INTO {table_name} 
            ({columns})
            VALUES
            ({col_values})""")

        for line in data:
            con.execute(test_statement, **line)
            
            
    print(f"{len(data)} rows inserted into {table_name}.")

# %%
# #load csv
# df = pd.read_csv('california_cities.csv')
# df.head()
# # check date column
# print(type(df['date'][0]))
# # change it
# df['date'] = pd.to_datetime(df['date'])
# # check again
# print(type(df['date'][0]))
# # load to sql
# df.to_sql(name='california_weather', if_exists='replace',con=engine, index=False,dtype=dtype)

# query = '''
# select * from california_weather
# '''

# df = pd.read_sql_query(query,engine)

# # check dates again
# print(type(df['date'][0]))
# df.head()


# df = format_date(pd.read_csv('california_cities.csv').dropna())
# df1 = format_date(pd.read_csv('test_data.csv').dropna())
# df2 = format_date(pd.read_csv('test_data2.csv').dropna())
# df3 = format_date(pd.read_csv('test_data3.csv').dropna())
# df4 = format_date(pd.read_csv('test_data4.csv').dropna())

#### Creates pre-loaded table with dtypes
# df.to_sql(name='california_weather', if_exists='replace',con=engine, index=False,dtype=dtype)

# push_to_sql(df1,'california_weather')
# push_to_sql(df2,'california_weather')
# push_to_sql(df3,'california_weather')
# push_to_sql(df4,'california_weather')

# gut_check = pd.read_sql_query(query, engine)
# gut_check.head()
# Out:
# 480 rows inserted into california_weather.
#            city  type          county       state      lat      lng  uv_index  \
# 0      Adelanto  City  San Bernardino  california  34.5828 -117.409      2.98
# 1  Agoura Hills  City     Los Angeles  california  34.1533 -118.762      3.00
# 2       Alameda  City         Alameda  california  37.7652 -122.242      2.00
# 3        Albany  City         Alameda  california  37.8869 -122.298      1.97
# 4      Alhambra  City     Los Angeles  california  34.0953 -118.127      3.00
#
#     aqi              category dominant_pollutant                date  \
# 0  41.0      Good air quality                 o3 2018-12-01 06:06:27
# 1  48.0      Good air quality               pm25 2018-12-01 06:06:27
# 2  61.0  Moderate air quality               pm25 2018-12-01 06:06:27
# 3  61.0  Moderate air quality               pm25 2018-12-01 06:06:27
# 4  66.0  Moderate air quality               pm25 2018-12-01 06:06:27
#
#    temperature  cloud  pressure  wind_speed  rain
# 0        13.95     75    1015.0         5.1  0.00
# 1        17.23     40    1016.0         3.6  0.00
# 2        14.29      1    1020.0         2.1  1.02
# 3        14.60      1    1020.0         2.1  1.02
# 4        17.37      1    1015.0         2.1  0.00

# %%
# inspector = inspect(engine)

# # check that schema is accurate w dtypes
# print(inspector.get_columns('california_weather'))

# # read new data
# new_db = pd.read_csv('test_data2.csv')
# new_db['date'] = pd.to_datetime(new_db['date'])
# new_db.head()


dtype2={ 
    'city':  sqlalchemy.types.VARCHAR(length=255),
    'type': sqlalchemy.types.VARCHAR(length=255),
    'county': sqlalchemy.types.VARCHAR(length=255),
    'state': sqlalchemy.types.VARCHAR(length=255),
    'lat': sqlalchemy.types.Float(precision=8, asdecimal=True),
    'lng': sqlalchemy.types.Float(precision=8, asdecimal=True)
} 

df = pd.read_csv('california_cities.csv')
# df.to_sql(name='california_cities',con=engine, index=False,dtype=dtype2)


query2='''select * from california_cities'''
pd.read_sql_query(query2,engine)
# Out:
#                  city  type           county       state      lat      lng
# 0            Adelanto  City   San Bernardino  california  34.5828 -117.409
# 1        Agoura Hills  City      Los Angeles  california  34.1533 -118.762
# 2             Alameda  City          Alameda  california  37.7652 -122.242
# 3              Albany  City          Alameda  california  37.8869 -122.298
# 4            Alhambra  City      Los Angeles  california  34.0953 -118.127
# 5         Aliso Viejo  City           Orange  california  33.5685 -117.726
# 6             Alturas  City            Modoc  california  41.4871 -120.542
# 7         Amador City  City           Amador  california  38.4194 -120.824
# 8     American Canyon  City             Napa  california  38.1749 -122.261
# 9             Anaheim  City           Orange  california  33.8366 -117.914
# 10           Anderson  City           Shasta  california  40.4482 -122.298
# 11        Angels Camp  City        Calaveras  california  38.0678 -120.539
# 12            Antioch  City     Contra Costa  california  38.0049 -121.806
# 13       Apple Valley  Town   San Bernardino  california  34.5008 -117.186
# 14            Arcadia  City      Los Angeles  california  34.1397 -118.035
# 15             Arcata  City         Humboldt  california  40.8665 -124.083
# 16      Arroyo Grande  City  San Luis Obispo  california  35.1186 -120.591
# 17            Artesia  City      Los Angeles  california  33.8658 -118.083
# 18              Arvin  City             Kern  california  35.2018 -118.833
# 19         Atascadero  City  San Luis Obispo  california  35.4894 -120.671
# 20           Atherton  Town        San Mateo  california  37.4613 -122.198
# 21            Atwater  City           Merced  california  37.3477 -120.609
# 22             Auburn  City           Placer  california  38.8966 -121.077
# 23             Avalon  City      Los Angeles  california  33.3428 -118.328
# 24             Avenal  City            Kings  california  36.0041 -120.129
# 25              Azusa  City      Los Angeles  california  34.1336 -117.908
# 26        Bakersfield  City             Kern  california  35.3733 -119.019
# 27       Baldwin Park  City      Los Angeles  california  34.0853 -117.961
# 28            Banning  City        Riverside  california  33.9256 -116.876
# 29            Barstow  City   San Bernardino  california  34.8958 -117.017
# ..                ...   ...              ...         ...      ...      ...
# 452             Vista  City        San Diego  california  33.2000 -117.243
# 453            Walnut  City      Los Angeles  california  34.0203 -117.865
# 454      Walnut Creek  City     Contra Costa  california  37.9101 -122.065
# 455             Wasco  City             Kern  california  35.5941 -119.341
# 456         Waterford  City       Stanislaus  california  37.6413 -120.760
# 457       Watsonville  City       Santa Cruz  california  36.9102 -121.757
# 458              Weed  City         Siskiyou  california  41.4226 -122.386
# 459       West Covina  City      Los Angeles  california  34.0686 -117.939
# 460    West Hollywood  City      Los Angeles  california  34.0900 -118.362
# 461   West Sacramento  City             Yolo  california  38.5805 -121.530
# 462  Westlake Village  City      Los Angeles  california  34.1466 -118.807
# 463       Westminster  City           Orange  california  33.7592 -117.990
# 464       Westmorland  City         Imperial  california  33.0373 -115.621
# 465         Wheatland  City             Yuba  california  39.0099 -121.423
# 466          Whittier  City      Los Angeles  california  33.9792 -118.033
# 467          Wildomar  City        Riverside  california  33.5989 -117.280
# 468          Williams  City           Colusa  california  39.1546 -122.149
# 469           Willits  City        Mendocino  california  39.4096 -123.356
# 470           Willows  City            Glenn  california  39.5243 -122.194
# 471           Windsor  Town           Sonoma  california  38.5471 -122.816
# 472           Winters  City             Yolo  california  38.5249 -121.971
# 473          Woodlake  City           Tulare  california  36.4136 -119.099
# 474          Woodland  City             Yolo  california  38.6785 -121.773
# 475          Woodside  Town        San Mateo  california  37.4299 -122.254
# 476       Yorba Linda  City           Orange  california  33.8885 -117.813
# 477        Yountville  Town             Napa  california  38.4016 -122.361
# 478             Yreka  City         Siskiyou  california  41.7354 -122.634
# 479         Yuba City  City           Sutter  california  39.1404 -121.617
# 480           Yucaipa  City   San Bernardino  california  34.0336 -117.043
# 481      Yucca Valley  Town   San Bernardino  california  34.1142 -116.432
#
# [482 rows x 6 columns]

# %%
query = '''select * from california_weather where day(date) = 5 and hour(date) between 00 and 01'''
test = pd.read_sql_query(query,engine)

# %%
# test['date'].value_counts()
test
# Out:
#                  city  type           county       state      lat      lng  \
# 0             Alameda  City          Alameda  california  37.7652 -122.242
# 1              Albany  City          Alameda  california  37.8869 -122.298
# 2         Aliso Viejo  City           Orange  california  33.5685 -117.726
# 3         Amador City  City           Amador  california  38.4194 -120.824
# 4     American Canyon  City             Napa  california  38.1749 -122.261
# 5            Anderson  City           Shasta  california  40.4482 -122.298
# 6         Angels Camp  City        Calaveras  california  38.0678 -120.539
# 7             Antioch  City     Contra Costa  california  38.0049 -121.806
# 358 2018-12-05 01:56:00        55.94     75   1013.00        3.60  0.00
# 359 2018-12-05 01:56:00        34.92     90   1018.00        0.76  0.00
# 360 2018-12-05 01:58:00        54.77     90   1015.00        4.10  0.42
# 361 2018-12-05 01:58:00        55.74      1   1015.00        7.70  0.00
# 362 2018-12-05 01:58:00        60.67     20   1014.00        2.56  0.00
# 363 2018-12-05 01:56:00        57.70     40   1015.00        1.50  0.00
# 364 2018-12-05 01:53:00        55.04     90   1011.00        1.50  0.00
# 365 2018-12-05 01:56:00        55.94     75   1013.00        3.60  0.00
# 366 2018-12-05 01:54:00        62.96      1   1012.00       10.30  0.00
# 367 2018-12-05 01:56:00        34.84     90   1018.00        1.36  0.00
# 368 2018-12-05 01:56:00        54.99     90   1015.00        4.10  0.38
# 369 2018-12-05 01:56:00        54.68     90   1014.00        2.60  0.25
# 370 2018-12-05 01:58:00        54.77     90   1015.00        4.10  0.42
# 371 2018-12-05 01:56:00        55.94     75   1013.00        3.60  0.00
# 372 2018-12-05 01:54:00        53.96     90   1015.00        2.10  0.00
# 373 2018-12-05 01:54:00        62.96      1   1012.00       10.30  0.00
# 374 2018-12-05 01:53:00        30.02     90   1018.00        5.10  0.00
# 375 2018-12-05 01:56:00        55.94     75   1013.00        3.60  0.00
# 376 2018-12-05 01:56:00        55.94     75   1013.00        3.60  0.00
# 377 2018-12-05 01:56:00        34.84     90   1018.00        1.36  0.00
#
# [378 rows x 16 columns]

# %%
# print(type(new_db['date'][0]))
# import pytz

from datetime import datetime
from pytz import timezone
import pytz

date = pytz.utc.localize(test['date'][0])
pst_time = date.astimezone(timezone('US/Pacific'))

d = datetime.strftime(date, '%Y-%m-%d %I:%M %p')
print(d)



print(date)
print(pst_time)

def utc_to_pst(date):
    d = pytz.utc.localize(date)
    pst = d.astimezone(timezone('US/Pacific'))
    parsed_pst = datetime.strftime(pst, '%Y-%m-%d %I:%M %p')
    
    return parsed_pst
# Out:
# 2018-12-05 12:15 AM
# 2018-12-05 00:15:00+00:00
# 2018-12-04 16:15:00-08:00

# %%
utc_to_pst(test['date'][0])
# Out:
# '2018-12-04 04:15 PM'

# %%
# query2 = '''select * from california_weather'''
# df = pd.read_sql_query(query2, engine)

# inspector = inspect(engine)
# inspector.get_columns('california_weather')
# len(df)

# %%
# new_df = pd.read_sql_query(query,engine)
# new_df['date'].value_counts()
# type(new_df['date'][0])

# %%
# print(data.keys())
# print(data.values())

# with engine.connect() as con:
    
#     statement = text("""INSERT INTO california_weather (city, type, county, state, lat, lng, uv_index, aqi, category, dominant_pollutant, date, temperature, cloud, pressure, wind_speed, rain) 
#     VALUES (:city, :type, :county, :state, :lat, :lng, :uv_index, :aqi, :category, :dominant_pollutant, :date, :temperature, :cloud, :pressure, :wind_speed, :rain)""")

#     for line in data.values():
#         con.execute(statement, **line)
        
#     con.execute(statement, **data)

# %%
# data = new_db.to_dict(orient='index')
# for v in data.values():
#     print(*v)
#     break
    
# print(**data)
